# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd
import requests
import json
import sklearn
from scipy import stats
from scipy.stats import norm
from sklearn.utils import resample
import pickle

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %%
response_1 = requests.get('https://api.spoonacular.com/recipes/search?id=716429&number=1&apiKey=c6943e3e749f4d5c8627c071b32cd36a')
example_recipe_name = response_1.json()
example_recipe_name
# Out:
# {'results': [{'id': 592479,
#    'title': 'Kale and Quinoa Salad with Black Beans',
#    'readyInMinutes': 50,
#    'servings': 6,
#    'image': 'Kale-and-Quinoa-Salad-with-Black-Beans-592479.jpg',
#    'imageUrls': ['Kale-and-Quinoa-Salad-with-Black-Beans-592479.jpg']}],
#  'baseUri': 'https://spoonacular.com/recipeImages/',
#  'offset': 0,
#  'number': 1,
#  'totalResults': 313853,
#  'processingTimeMs': 650,
#  'expires': 1579466850458}

# %%
response_1_info = requests.get('https://api.spoonacular.com/recipes/592479/information?includeNutrition=true&apiKey=c6943e3e749f4d5c8627c071b32cd36a')
example_recipe_info = response_1_info.json()
example_recipe_info
# Out:
# {'vegetarian': True,
#  'vegan': True,
#  'glutenFree': True,
#  'dairyFree': True,
#  'veryHealthy': True,
#  'cheap': False,
#  'veryPopular': True,
#  'sustainable': False,
#  'weightWatcherSmartPoints': 6,
#  'gaps': 'no',
#  'lowFodmap': False,
#  'ketogenic': False,
#  'whole30': False,
#  'preparationMinutes': 25,
#  'cookingMinutes': 25,
#  'sourceUrl': 'http://blog.fatfreevegan.com/2013/06/kale-and-quinoa-salad-with-black-beans.html',
#  'spoonacularSourceUrl': 'https://spoonacular.com/kale-and-quinoa-salad-with-black-beans-592479',
#  'aggregateLikes': 50078,
#  'spoonacularScore': 100.0,
#  'healthScore': 100.0,
#  'creditsText': 'Fat Free Vegan',
#  'sourceName': 'Fat Free Vegan',
#  'pricePerServing': 101.23,
#  'extendedIngredients': [{'id': 1022009,
#    'aisle': 'Ethnic Foods;Spices and Seasonings',
#    'image': 'chili-powder.jpg',
#    'consitency': 'solid',
#    'name': 'ancho chile powder',
#    'original': '1 teaspoon ancho chile powder (or other pure chile powder, not a blend)',
#    'originalString': '1 teaspoon ancho chile powder (or other pure chile powder, not a blend)',
#    'originalName': 'ancho chile powder (or other pure chile powder, not a blend)',
#    'amount': 1.0,
#    'unit': 'teaspoon',
#    'meta': ['pure', '(or other chile powder, not a blend)'],
#    'metaInformation': ['pure', '(or other chile powder, not a blend)'],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'tsp',
#      'unitLong': 'teaspoon'},
#     'metric': {'amount': 1.0, 'unitShort': 'tsp', 'unitLong': 'teaspoon'}}},
#   {'id': 9037,
#    'aisle': 'Produce',
#    'image': 'avocado.jpg',
#    'consitency': 'solid',
#    'name': 'avocado',
#    'original': '1 avocado, sliced or cubed (optional)',
#    'originalString': '1 avocado, sliced or cubed (optional)',
#    'originalName': 'avocado, sliced or cubed (optional)',
#    'amount': 1.0,
#    'unit': '',
#    'meta': ['cubed', 'sliced'],
#    'metaInformation': ['cubed', 'sliced'],
#    'measures': {'us': {'amount': 1.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 1.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 16015,
#    'aisle': 'Pasta and Rice;Canned and Jarred',
#    'image': 'black-beans.jpg',
#    'consitency': 'solid',
#    'name': 'black beans',
#    'original': '1 15-ounce can black beans, rinsed and drained (about 1 1/2 cups)',
#    'originalString': '1 15-ounce can black beans, rinsed and drained (about 1 1/2 cups)',
#    'originalName': '15-ounce can black beans, rinsed and drained (about',
#    'amount': 1.5,
#    'unit': 'cups',
#    'meta': ['rinsed', 'drained', 'canned'],
#    'metaInformation': ['rinsed', 'drained', 'canned'],
#    'measures': {'us': {'amount': 1.5, 'unitShort': 'cups', 'unitLong': 'cups'},
#     'metric': {'amount': 354.882,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 11124,
#    'aisle': 'Produce',
#    'image': 'sliced-carrot.png',
#    'consitency': 'solid',
#    'name': 'carrot',
#    'original': '1/2 cup grated carrot',
#    'originalString': '1/2 cup grated carrot',
#    'originalName': 'grated carrot',
#    'amount': 0.5,
#    'unit': 'cup',
#    'meta': ['grated'],
#    'metaInformation': ['grated'],
#    'measures': {'us': {'amount': 0.5, 'unitShort': 'cups', 'unitLong': 'cups'},
#     'metric': {'amount': 118.294,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 2009,
#    'aisle': 'Spices and Seasonings',
#    'image': 'chili-powder.jpg',
#    'consitency': 'solid',
#    'name': 'chile powder',
#    'original': '1/4 teaspoon chipotle chile powder, or to taste',
#    'originalString': '1/4 teaspoon chipotle chile powder, or to taste',
#    'originalName': 'chipotle chile powder, or to taste',
#    'amount': 0.25,
#    'unit': 'teaspoon',
#    'meta': ['to taste'],
#    'metaInformation': ['to taste'],
#    'measures': {'us': {'amount': 0.25,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'},
#     'metric': {'amount': 0.25, 'unitShort': 'tsps', 'unitLong': 'teaspoons'}}},
#   {'id': 1002014,
#    'aisle': 'Spices and Seasonings',
#    'image': 'ground-cumin.jpg',
#    'consitency': 'solid',
#    'name': 'cumin',
#    'original': '1/2 teaspoon cumin',
#    'originalString': '1/2 teaspoon cumin',
#    'originalName': 'cumin',
#    'amount': 0.5,
#    'unit': 'teaspoon',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 0.5,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'},
#     'metric': {'amount': 0.5, 'unitShort': 'tsps', 'unitLong': 'teaspoons'}}},
#   {'id': 11215,
#    'aisle': 'Produce',
#    'image': 'garlic.jpg',
#    'consitency': 'solid',
#    'name': 'garlic',
#    'original': '2 cloves garlic, minced',
#    'originalString': '2 cloves garlic, minced',
#    'originalName': 'garlic, minced',
#    'amount': 2.0,
#    'unit': 'cloves',
#    'meta': ['minced'],
#    'metaInformation': ['minced'],
#    'measures': {'us': {'amount': 2.0,
#      'unitShort': 'cloves',
#      'unitLong': 'cloves'},
#     'metric': {'amount': 2.0, 'unitShort': 'cloves', 'unitLong': 'cloves'}}},
#   {'id': 12220,
#    'aisle': 'Health Foods;Baking',
#    'image': 'flax-seeds.png',
#    'consitency': 'solid',
#    'name': 'ground flaxseed',
#    'original': '1 teaspoon chia seeds or ground flaxseed',
#    'originalString': '1 teaspoon chia seeds or ground flaxseed',
#    'originalName': 'chia seeds or ground flaxseed',
#    'amount': 1.0,
#    'unit': 'teaspoon',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'tsp',
#      'unitLong': 'teaspoon'},
#     'metric': {'amount': 1.0, 'unitShort': 'tsp', 'unitLong': 'teaspoon'}}},
#   {'id': 11233,
#    'aisle': 'Produce',
#    'image': 'kale.jpg',
#    'consitency': 'solid',
#    'name': 'kale',
#    'original': '4 – 6 cups chopped kale leaves (about 4-5 ounces)',
#    'originalString': '4 – 6 cups chopped kale leaves (about 4-5 ounces)',
#    'originalName': '– 6 cups chopped kale leaves (about',
#    'amount': 4.0,
#    'unit': 'ounces',
#    'meta': ['chopped'],
#    'metaInformation': ['chopped'],
#    'measures': {'us': {'amount': 4.0, 'unitShort': 'oz', 'unitLong': 'ounces'},
#     'metric': {'amount': 113.398, 'unitShort': 'g', 'unitLong': 'grams'}}},
#   {'id': 9152,
#    'aisle': 'Produce',
#    'image': 'lemon-juice.jpg',
#    'consitency': 'liquid',
#    'name': 'lemon juice',
#    'original': 'additional lemon juice and seasonings, to taste',
#    'originalString': 'additional lemon juice and seasonings, to taste',
#    'originalName': 'additional lemon juice and seasonings, to taste',
#    'amount': 6.0,
#    'unit': 'servings',
#    'meta': ['to taste'],
#    'metaInformation': ['to taste'],
#    'measures': {'us': {'amount': 6.0,
#      'unitShort': 'servings',
#      'unitLong': 'servings'},
#     'metric': {'amount': 6.0,
#      'unitShort': 'servings',
#      'unitLong': 'servings'}}},
#   {'id': 9160,
#    'aisle': 'Produce',
#    'image': 'lime-juice.png',
#    'consitency': 'liquid',
#    'name': 'lime juice',
#    'original': '1/4 cup freshly squeezed lemon or lime juice',
#    'originalString': '1/4 cup freshly squeezed lemon or lime juice',
#    'originalName': 'freshly squeezed lemon or lime juice',
#    'amount': 0.25,
#    'unit': 'cup',
#    'meta': ['freshly squeezed'],
#    'metaInformation': ['freshly squeezed'],
#    'measures': {'us': {'amount': 0.25,
#      'unitShort': 'cups',
#      'unitLong': 'cups'},
#     'metric': {'amount': 59.147,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 20035,
#    'aisle': 'Pasta and Rice;Health Foods',
#    'image': 'uncooked-quinoa.png',
#    'consitency': 'solid',
#    'name': 'quinoa',
#    'original': '1 cup quinoa, rinsed very well (I used a combo of red and white quinoa)',
#    'originalString': '1 cup quinoa, rinsed very well (I used a combo of red and white quinoa)',
#    'originalName': 'quinoa, rinsed very well (I used a combo of red and white quinoa)',
#    'amount': 1.0,
#    'unit': 'cup',
#    'meta': ['white',
#     'red',
#     'rinsed',
#     'well',
#     '(I used a combo of and quinoa)'],
#    'metaInformation': ['white',
#     'red',
#     'rinsed',
#     'well',
#     '(I used a combo of and quinoa)'],
#    'measures': {'us': {'amount': 1.0, 'unitShort': 'cup', 'unitLong': 'cup'},
#     'metric': {'amount': 236.588,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 11821,
#    'aisle': 'Produce',
#    'image': 'red-pepper.jpg',
#    'consitency': 'solid',
#    'name': 'red bell pepper',
#    'original': '1/2 red bell pepper, chopped',
#    'originalString': '1/2 red bell pepper, chopped',
#    'originalName': 'red bell pepper, chopped',
#    'amount': 0.5,
#    'unit': '',
#    'meta': ['red', 'chopped'],
#    'metaInformation': ['red', 'chopped'],
#    'measures': {'us': {'amount': 0.5, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 0.5, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 2047,
#    'aisle': 'Spices and Seasonings',
#    'image': 'salt.jpg',
#    'consitency': 'solid',
#    'name': 'salt',
#    'original': '1/2 tsp salt, or to taste (optional)',
#    'originalString': '1/2 tsp salt, or to taste (optional)',
#    'originalName': 'salt, or to taste (optional)',
#    'amount': 0.5,
#    'unit': 'tsp',
#    'meta': ['to taste'],
#    'metaInformation': ['to taste'],
#    'measures': {'us': {'amount': 0.5,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'},
#     'metric': {'amount': 0.5, 'unitShort': 'tsps', 'unitLong': 'teaspoons'}}},
#   {'id': 6615,
#    'aisle': 'Canned and Jarred',
#    'image': 'chicken-broth.png',
#    'consitency': 'liquid',
#    'name': 'vegetable broth',
#    'original': '3 tablespoons vegetable broth',
#    'originalString': '3 tablespoons vegetable broth',
#    'originalName': 'vegetable broth',
#    'amount': 3.0,
#    'unit': 'tablespoons',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 3.0,
#      'unitShort': 'Tbsps',
#      'unitLong': 'Tbsps'},
#     'metric': {'amount': 3.0, 'unitShort': 'Tbsps', 'unitLong': 'Tbsps'}}}],
#  'id': 592479,
#  'title': 'Kale and Quinoa Salad with Black Beans',
#  'readyInMinutes': 50,
#  'servings': 6,
#  'image': 'https://spoonacular.com/recipeImages/592479-556x370.jpg',
#  'imageType': 'jpg',
#  'nutrition': {'nutrients': [{'title': 'Calories',
#     'amount': 242.6,
#     'unit': 'cal',
#     'percentOfDailyNeeds': 12.13},
#    {'title': 'Fat', 'amount': 7.38, 'unit': 'g', 'percentOfDailyNeeds': 11.35},
#    {'title': 'Saturated Fat',
#     'amount': 1.03,
#     'unit': 'g',
#     'percentOfDailyNeeds': 6.43},
#    {'title': 'Carbohydrates',
#     'amount': 37.19,
#     'unit': 'g',
#     'percentOfDailyNeeds': 12.4},
#    {'title': 'Sugar', 'amount': 1.8, 'unit': 'g', 'percentOfDailyNeeds': 2.0},
#    {'title': 'Cholesterol',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'title': 'Sodium',
#     'amount': 250.66,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 10.9},
#    {'title': 'Protein',
#     'amount': 9.79,
#     'unit': 'g',
#     'percentOfDailyNeeds': 19.58},
#    {'title': 'Vitamin K',
#     'amount': 142.68,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 135.88},
#    {'title': 'Vitamin A',
#     'amount': 4183.66,
#     'unit': 'IU',
#     'percentOfDailyNeeds': 83.67},
#    {'title': 'Vitamin C',
#     'amount': 48.48,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 58.77},
#    {'title': 'Manganese',
#     'amount': 1.01,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 50.36},
#    {'title': 'Folate',
#     'amount': 160.25,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 40.06},
#    {'title': 'Fiber',
#     'amount': 8.84,
#     'unit': 'g',
#     'percentOfDailyNeeds': 35.34},
#    {'title': 'Copper',
#     'amount': 0.63,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 31.42},
#    {'title': 'Magnesium',
#     'amount': 111.48,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 27.87},
#    {'title': 'Phosphorus',
#     'amount': 239.17,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 23.92},
#    {'title': 'Vitamin B6',
#     'amount': 0.38,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 19.13},
#    {'title': 'Potassium',
#     'amount': 667.61,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 19.07},
#    {'title': 'Vitamin B1',
#     'amount': 0.28,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 18.55},
#    {'title': 'Iron',
#     'amount': 2.98,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 16.53},
#    {'title': 'Vitamin B2',
#     'amount': 0.21,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 12.24},
#    {'title': 'Vitamin E',
#     'amount': 1.82,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 12.15},
#    {'title': 'Zinc',
#     'amount': 1.8,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 11.99},
#    {'title': 'Vitamin B5',
#     'amount': 0.91,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 9.11},
#    {'title': 'Vitamin B3',
#     'amount': 1.72,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 8.61},
#    {'title': 'Calcium',
#     'amount': 69.53,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 6.95},
#    {'title': 'Selenium',
#     'amount': 3.59,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 5.14}],
#   'ingredients': [{'name': 'ancho chile powder',
#     'amount': 0.17,
#     'unit': 'teaspoon',
#     'nutrients': [{'name': 'Mono Unsaturated Fat',
#       'amount': 0.01,
#       'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.03, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.13, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.12, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.04, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.04, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 0.09, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 98.83, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 1.1, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 6.5, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 0.5, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 5.47, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.05, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.35, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.07, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 0.17, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 0.94, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.06, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.22, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.02, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 1.0, 'unit': 'mg'}]},
#    {'name': 'avocado',
#     'amount': 0.17,
#     'unit': '',
#     'nutrients': [{'name': 'Mono Unsaturated Fat',
#       'amount': 3.28,
#       'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.61, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.69, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.06, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 3.35, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 2.24, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.58, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.67, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.71, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 27.14, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 48.91, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 4.02, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.05, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.21, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.47, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 162.48, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 9.72, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 2.35, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 4.91, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 7.04, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.13, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 2.86, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 53.6, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.18, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.04, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.09, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 4.76, 'unit': 'mg'},
#      {'name': 'Fluoride', 'amount': 2.35, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.22, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 17.42, 'unit': 'mg'}]},
#    {'name': 'black beans',
#     'amount': 0.25,
#     'unit': 'cups',
#     'nutrients': [{'name': 'Mono Unsaturated Fat',
#       'amount': 0.02,
#       'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.1, 'unit': 'g'},
#      {'name': 'Copper', 'amount': 0.09, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 3.74, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.22, 'unit': 'mg'},
#      {'name': 'Protein', 'amount': 3.81, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.06, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 64.07, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.1, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 2.58, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 11.61, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.19, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.48, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.1, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 152.65, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 30.1, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 0.43, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.23, 'unit': 'g'},
#      {'name': 'Selenium', 'amount': 0.52, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 10.2, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 56.76, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.9, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.03, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.03, 'unit': 'mg'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 60.2, 'unit': 'mg'}]},
#    {'name': 'carrot',
#     'amount': 0.08,
#     'unit': 'cup',
#     'nutrients': [{'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.07, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 0.63, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.3, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.1, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.1, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 2.03, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 1781.97, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 3.52, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.03, 'unit': 'mg'},
#      {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin B5', 'amount': 0.03, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 34.13, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 1.28, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 7.36, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.03, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 1.41, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 1.02, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 4.37, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.03, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.94, 'unit': 'mg'},
#      {'name': 'Fluoride', 'amount': 0.34, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.51, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 3.73, 'unit': 'mg'}]},
#    {'name': 'chile powder',
#     'amount': 0.04,
#     'unit': 'teaspoon',
#     'nutrients': [{'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.03, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.03, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 0.02, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 24.71, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 0.27, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 1.63, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 0.12, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 1.37, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.09, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.02, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 0.04, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 0.24, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.06, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 0.25, 'unit': 'mg'}]},
#    {'name': 'cumin',
#     'amount': 0.08,
#     'unit': 'teaspoon',
#     'nutrients': [{'name': 'Mono Unsaturated Fat',
#       'amount': 0.02,
#       'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.02, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.03, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 0.02, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 2.12, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 1.55, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 2.98, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 0.61, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 0.28, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.04, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.01, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 0.07, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 0.63, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.11, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.04, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 0.83, 'unit': 'mg'}]},
#    {'name': 'garlic',
#     'amount': 0.33,
#     'unit': 'cloves',
#     'nutrients': [{'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 0.31, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.02, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.06, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 0.03, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 0.09, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 1.81, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 4.01, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 0.25, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 0.17, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.02, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.14, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 0.33, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 1.49, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.23, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 1.53, 'unit': 'mg'}]},
#    {'name': 'ground flaxseed',
#     'amount': 0.17,
#     'unit': 'teaspoon',
#     'nutrients': [{'name': 'Mono Unsaturated Fat',
#       'amount': 0.03,
#       'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.1, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.09, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.06, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 0.29, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 0.85, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 2.71, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 1.31, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 0.1, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.14, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.01, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.08, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 0.1, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 1.78, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.26, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 2.14, 'unit': 'mg'}]},
#    {'name': 'kale',
#     'amount': 0.67,
#     'unit': 'ounces',
#     'nutrients': [{'name': 'Mono Unsaturated Fat',
#       'amount': 0.01,
#       'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.06, 'unit': 'g'},
#      {'name': 'Copper', 'amount': 0.28, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 22.68, 'unit': 'mg'},
#      {'name': 'Vitamin B3', 'amount': 0.19, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.81, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.02, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 5.86, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 1888.08, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 28.35, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.12, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.11, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 92.8, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 8.88, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 7.18, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.18, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 133.2, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.17, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 1.65, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 9.26, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.28, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.05, 'unit': 'mg'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 17.39, 'unit': 'mg'}]},
#    {'name': 'lemon juice',
#     'amount': 1.0,
#     'unit': 'servings',
#     'nutrients': [{'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 5.81, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.05, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.05, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 3.0, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 0.9, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 0.9, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin B5', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 15.45, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 0.9, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 0.15, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.04, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.02, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 1.03, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 3.3, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.77, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.38, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 1.2, 'unit': 'mg'}]},
#    {'name': 'lime juice',
#     'amount': 0.04,
#     'unit': 'cup',
#     'nutrients': [{'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 3.03, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.04, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.04, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 1.01, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 5.04, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 1.41, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 11.8, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 0.81, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 0.2, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.06, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 0.85, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 2.52, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.51, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.17, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 1.41, 'unit': 'mg'}]},
#    {'name': 'quinoa',
#     'amount': 0.17,
#     'unit': 'cup',
#     'nutrients': [{'name': 'Mono Unsaturated Fat',
#       'amount': 0.46,
#       'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.93, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.69, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.17, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Fiber', 'amount': 1.98, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.43, 'unit': 'mg'},
#      {'name': 'Protein', 'amount': 4.0, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.2, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 52.13, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.1, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 3.97, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 13.32, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.58, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.88, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.22, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 159.52, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 55.82, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 1.42, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 1.72, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 2.41, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 18.18, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 104.27, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 1.29, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.09, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.14, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 19.89, 'unit': 'mg'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 129.48, 'unit': 'mg'}]},
#    {'name': 'red bell pepper',
#     'amount': 0.08,
#     'unit': '',
#     'nutrients': [{'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.16, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 12.66, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.21, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.1, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.1, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 4.56, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 310.49, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 0.69, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.03, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 20.92, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 1.19, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 0.4, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.03, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.49, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 0.6, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 3.07, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.04, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.03, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.56, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.42, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 2.58, 'unit': 'mg'}]},
#    {'name': 'salt',
#     'amount': 0.08,
#     'unit': 'tsp',
#     'nutrients': [{'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#      {'name': 'Calcium', 'amount': 0.12, 'unit': 'mg'},
#      {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Potassium', 'amount': 0.04, 'unit': 'mg'},
#      {'name': 'Magnesium', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Sodium', 'amount': 193.79, 'unit': 'mg'},
#      {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 0.0, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Choline', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fluoride', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#      {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'}]},
#    {'name': 'vegetable broth',
#     'amount': 0.5,
#     'unit': 'tablespoons',
#     'nutrients': [{'name': 'Calcium', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Sodium', 'amount': 30.0, 'unit': 'mg'},
#      {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Carbohydrates', 'amount': 0.1, 'unit': 'g'},
#      {'name': 'Calories', 'amount': 0.38, 'unit': 'cal'},
#      {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#      {'name': 'Sugar', 'amount': 0.06, 'unit': 'g'},
#      {'name': 'Vitamin A', 'amount': 15.98, 'unit': 'IU'}]}],
#   'caloricBreakdown': {'percentProtein': 15.4,
#    'percentFat': 26.11,
#    'percentCarbs': 58.49},
#   'weightPerServing': {'amount': 179, 'unit': 'g'}},
#  'cuisines': [],
#  'dishTypes': ['side dish'],
#  'diets': ['gluten free', 'dairy free', 'lacto ovo vegetarian', 'vegan'],
#  'occasions': [],
#  'winePairing': {},
#  'instructions': 'Instructions  Heat a saucepan. Add the rinsed and drained quinoa and the garlic and toast it until almost dry. Add the vegetable broth, bring to a boil, reduce heat, and cover. Simmer until all the water is absorbed, about 20 minutes. Remove from heat and allow to cool. While the quinoa is cooking, make the dressing in a small bowl or measuring cup: whisk together the lemon juice, 3 tablespoons broth, chia/flax seeds, chile powders, cumin, and salt. Allow to stand until the chia seeds start to thicken the dressing. Place the kale in a large serving bowl. Add half of the dressing and massage it into the kale using a wringing motion until the kale is very tender. Two minutes of massaging should do it, but the longer, the better. Add the quinoa, black beans, carrot, and bell pepper, along with the remaining dressing. Mix well and refrigerate until ready to serve. Just before serving, check the seasoning and add more lemon juice, chile powder, cumin, and salt, as needed. Stir in chopped avocado, if desired, or serve with slices of avocado on the side.',
#  'analyzedInstructions': [{'name': '',
#    'steps': [{'number': 1,
#      'step': 'Heat a saucepan.',
#      'ingredients': [],
#      'equipment': [{'id': 404669,
#        'name': 'sauce pan',
#        'image': 'sauce-pan.jpg'}]},
#     {'number': 2,
#      'step': 'Add the rinsed and drained quinoa and the garlic and toast it until almost dry.',
#      'ingredients': [{'id': 11215, 'name': 'garlic', 'image': 'garlic.png'},
#       {'id': 20035, 'name': 'quinoa', 'image': 'uncooked-quinoa.png'}],
#      'equipment': []},
#     {'number': 3,
#      'step': 'Add the vegetable broth, bring to a boil, reduce heat, and cover. Simmer until all the water is absorbed, about 20 minutes.',
#      'ingredients': [{'id': 6615,
#        'name': 'vegetable broth',
#        'image': 'chicken-broth.png'}],
#      'equipment': [],
#      'length': {'number': 20, 'unit': 'minutes'}},
#     {'number': 4,
#      'step': 'Remove from heat and allow to cool. While the quinoa is cooking, make the dressing in a small bowl or measuring cup: whisk together the lemon juice, 3 tablespoons broth, chia/flax seeds, chile powders, cumin, and salt. Allow to stand until the chia seeds start to thicken the dressing.',
#      'ingredients': [{'id': 9152,
#        'name': 'lemon juice',
#        'image': 'lemon-juice.jpg'},
#       {'id': 10012220, 'name': 'flaxseed', 'image': 'flax-seeds.png'},
#       {'id': 20035, 'name': 'quinoa', 'image': 'uncooked-quinoa.png'},
#       {'id': 1006615, 'name': 'broth', 'image': 'chicken-broth.png'},
#       {'id': 1002014, 'name': 'cumin', 'image': 'ground-cumin.jpg'},
#       {'id': 2047, 'name': 'salt', 'image': 'salt.jpg'}],
#      'equipment': [{'id': 404766,
#        'name': 'measuring cup',
#        'image': 'measuring-cup.jpg'},
#       {'id': 404661, 'name': 'whisk', 'image': 'whisk.png'},
#       {'id': 404783, 'name': 'bowl', 'image': 'bowl.jpg'}]},
#     {'number': 5,
#      'step': 'Place the kale in a large serving bowl.',
#      'ingredients': [{'id': 11233, 'name': 'kale', 'image': 'kale.jpg'}],
#      'equipment': [{'id': 404783, 'name': 'bowl', 'image': 'bowl.jpg'}]},
#     {'number': 6,
#      'step': 'Add half of the dressing and massage it into the kale using a wringing motion until the kale is very tender. Two minutes of massaging should do it, but the longer, the better.',
#      'ingredients': [{'id': 11233, 'name': 'kale', 'image': 'kale.jpg'}],
#      'equipment': [],
#      'length': {'number': 2, 'unit': 'minutes'}},
#     {'number': 7,
#      'step': 'Add the quinoa, black beans, carrot, and bell pepper, along with the remaining dressing.',
#      'ingredients': [{'id': 10211821,
#        'name': 'bell pepper',
#        'image': 'bell-pepper-orange.png'},
#       {'id': 16015, 'name': 'black beans', 'image': 'black-beans.jpg'},
#       {'id': 11124, 'name': 'carrot', 'image': 'sliced-carrot.png'},
#       {'id': 20035, 'name': 'quinoa', 'image': 'uncooked-quinoa.png'}],
#      'equipment': []},
#     {'number': 8,
#      'step': 'Mix well and refrigerate until ready to serve. Just before serving, check the seasoning and add more lemon juice, chile powder, cumin, and salt, as needed. Stir in chopped avocado, if desired, or serve with slices of avocado on the side.',
#      'ingredients': [{'id': 2009,
#        'name': 'chili powder',
#        'image': 'chili-powder.jpg'},
#       {'id': 9152, 'name': 'lemon juice', 'image': 'lemon-juice.jpg'},
#       {'id': 9037, 'name': 'avocado', 'image': 'avocado.jpg'},
#       {'id': 1002014, 'name': 'cumin', 'image': 'ground-cumin.jpg'},
#       {'id': 2047, 'name': 'salt', 'image': 'salt.jpg'}],
#      'equipment': []}]}]}

# %%
type(example_recipe_info)
# Out:
# dict

# %%
example_recipe_info_keys = list(example_recipe_info.keys())
example_recipe_info_keys
# Out:
# ['vegetarian',
#  'vegan',
#  'glutenFree',
#  'dairyFree',
#  'veryHealthy',
#  'cheap',
#  'veryPopular',
#  'sustainable',
#  'weightWatcherSmartPoints',
#  'gaps',
#  'lowFodmap',
#  'ketogenic',
#  'whole30',
#  'preparationMinutes',
#  'cookingMinutes',
#  'sourceUrl',
#  'spoonacularSourceUrl',
#  'aggregateLikes',
#  'spoonacularScore',
#  'healthScore',
#  'creditsText',
#  'sourceName',
#  'pricePerServing',
#  'extendedIngredients',
#  'id',
#  'title',
#  'readyInMinutes',
#  'servings',
#  'image',
#  'imageType',
#  'nutrition',
#  'cuisines',
#  'dishTypes',
#  'diets',
#  'occasions',
#  'winePairing',
#  'instructions',
#  'analyzedInstructions']

# %%
#the unique id for the recipe:
example_recipe_info['id']
# Out:
# 592479

# %%
#looks like the "nutrition" value for a recipe is typically very long...we just want calories. 
print(example_recipe_info['nutrition']['nutrients'][0]['title'])
#here is how we get the calorie quantity:
example_recipe_info['nutrition']['nutrients'][0]['amount']
# Out:
# Calories
# 242.6

# %%
#How long it takes to prepare the recipe.
print('Recipe Total Time (In Minutes)')
example_recipe_info['readyInMinutes']
# Out:
# Recipe Total Time (In Minutes)
# 50

# %%
#number of "likes" on a particular recipe.
print('Recipe Number Of Likes')
example_recipe_info['aggregateLikes']
# Out:
# Recipe Number Of Likes
# 50078

# %%
#Spoonacular's "score" for a particular recipe.
print('Recipe Spoonacular Score (0-100)')
example_recipe_info['spoonacularScore']
# Out:
# Recipe Spoonacular Score (0-100)
# 100.0

# %%
#price per serving (in cents)
print('Price Per Serving (In Cents)')
example_recipe_info['pricePerServing']
# Out:
# Price Per Serving (In Cents)
# 101.23

# %%
print('Number Of Servings')
example_recipe_info['servings']
# Out:
# Number Of Servings
# 6

# %%
total_price = example_recipe_info['servings'] * example_recipe_info['pricePerServing']
print('Total Price For Recipe (In Dollars)')
round(total_price / 100,2)
# Out:
# Total Price For Recipe (In Dollars)
# 6.07

# %% [markdown]
# # Trip Advisor API

# %%
url = "https://tripadvisor1.p.rapidapi.com/reviews/list"

querystring = {"limit":"1","currency":"USD","lang":"en_US","location_id":"8014024"}

headers = {
    'x-rapidapi-host': "tripadvisor1.p.rapidapi.com",
    'x-rapidapi-key': "e1834ce5c0mshd672556248feb69p18ef70jsncbd79662d6cb"
    }

response_2 = requests.request("GET", url, headers=headers, params=querystring)
response_2.json()
# Out:
# {'data': [{'id': '738977018',
#    'lang': 'en',
#    'location_id': '8014024',
#    'published_date': '2020-01-13T14:25:57-05:00',
#    'rating': '5',
#    'type': 'review',
#    'helpful_votes': '0',
#    'url': 'https://www.tripadvisor.com/ShowUserReviews-g293928-d8014024-r738977018-LegendSea_Hotel-Nha_Trang_Khanh_Hoa_Province.html#review738977018',
#    'travel_date': '2020-01',
#    'text': 'Cheap complete breakfast at less than 3 USD. I loved the tomatoes and omellete.\nGood coffee\nRooftop pool\nBeach view\n\nOne of the best breakfast experience I had!\nI will come back for sure \n\nCentrally located too...\nFew minutes to the beach\n\n🥓☕️',
#    'user': {'user_id': '0297276CCFC9071B7805C00A63D99072',
#     'type': 'user',
#     'first_name': None,
#     'last_initial': None,
#     'name': None,
#     'reviewer_type': 'Senior Contributor',
#     'contributions': {'reviews': '33',
#      'review_city_count': '11',
#      'restaurant_reviews': '18',
#      'hotel_reviews': '9',
#      'attraction_reviews': '6',
#      'helpful_votes': '0',
#      'photos_count': '24',
#      'badges_count': '5',
#      'avatar_thumbnail_url': 'https://media-cdn.tripadvisor.com/media/photo-t/01/2e/70/72/avatar054.jpg',
#      'avatar_url': 'https://media-cdn.tripadvisor.com/media/photo-f/01/2e/70/72/avatar054.jpg'},
#     'member_id': '0',
#     'username': 'Nenenprado16',
#     'user_location': {'name': 'Nha Trang, Vietnam', 'id': '293928'},
#     'avatar': {'small': {'url': 'https://media-cdn.tripadvisor.com/media/photo-t/01/2e/70/72/avatar054.jpg'},
#      'large': {'url': 'https://media-cdn.tripadvisor.com/media/photo-l/01/2e/70/72/avatar054.jpg'}},
#     'link': 'https://www.tripadvisor.com/MemberProfile-a_uid.0297276CCFC9071B7805C00A63D99072',
#     'points': '0',
#     'created_time': '2017-10-29T09:08:52-0400',
#     'locale': 'en_PH'},
#    'title': 'Best affordable breakfast in rooftop pool',
#    'owner_response': None,
#    'subratings': [],
#    'machine_translated': False,
#    'machine_translatable': False,
#    'photos': [{'id': '446189793',
#      'locations': [{'name': 'LegendSea Hotel',
#        'id': '8014024',
#        'web_url': 'https://www.tripadvisor.com/Hotel_Review-g293928-d8014024-Reviews-LegendSea_Hotel-Nha_Trang_Khanh_Hoa_Province.html',
#        'intent_url': 'tripadvisor:///Hotel_Review-g293928-d8014024-Reviews-LegendSea_Hotel-Nha_Trang_Khanh_Hoa_Province.html',
#        'parent_location_id': 293928}],
#      'published_date': '2020-01-13T19:25:56-0500',
#      'user': {'username': 'Nenenprado16',
#       'member_id': '0',
#       'user_id': '0297276CCFC9071B7805C00A63D99072',
#       'type': 'user',
#       'avatar': {'id': '19820658',
#        'published_date': '2009-06-23T13:06:54-0400',
#        'helpful_votes': '0',
#        'is_blessed': False,
#        'uploaded_date': '2009-06-23T13:06:54-0400',
#        'images': {'small': {'url': 'https://media-cdn.tripadvisor.com/media/photo-l/01/2e/70/72/avatar054.jpg',
#          'width': '150',
#          'height': '150'},
#         'thumbnail': {'url': 'https://media-cdn.tripadvisor.com/media/photo-t/01/2e/70/72/avatar054.jpg',
#          'width': '50',
#          'height': '50'},
#         'large': {'url': 'https://media-cdn.tripadvisor.com/media/photo-s/01/2e/70/72/avatar054.jpg',
#          'width': '74',
#          'height': '74'},
#         'medium': {'url': 'https://media-cdn.tripadvisor.com/media/photo-f/01/2e/70/72/avatar054.jpg',
#          'width': '205',
#          'height': '205'}}}},
#      'helpful_votes': '0',
#      'is_blessed': False,
#      'uploaded_date': '2020-01-13T19:25:56-0500',
#      'images': {'small': {'url': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/98/50/e1/photo0jpg.jpg',
#        'width': '150',
#        'height': '150'},
#       'thumbnail': {'url': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/98/50/e1/photo0jpg.jpg',
#        'width': '50',
#        'height': '50'},
#       'original': {'url': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/98/50/e1/photo0jpg.jpg',
#        'width': '1536',
#        'height': '2048'},
#       'large': {'url': 'https://media-cdn.tripadvisor.com/media/photo-s/1a/98/50/e1/photo0jpg.jpg',
#        'width': '338',
#        'height': '450'},
#       'medium': {'url': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/98/50/e1/photo0jpg.jpg',
#        'width': '154',
#        'height': '205'}}},
#     {'id': '446189794',
#      'locations': [{'name': 'LegendSea Hotel',
#        'id': '8014024',
#        'web_url': 'https://www.tripadvisor.com/Hotel_Review-g293928-d8014024-Reviews-LegendSea_Hotel-Nha_Trang_Khanh_Hoa_Province.html',
#        'intent_url': 'tripadvisor:///Hotel_Review-g293928-d8014024-Reviews-LegendSea_Hotel-Nha_Trang_Khanh_Hoa_Province.html',
#        'parent_location_id': 293928}],
#      'published_date': '2020-01-13T19:25:56-0500',
#      'user': {'username': 'Nenenprado16',
#       'member_id': '0',
#       'user_id': '0297276CCFC9071B7805C00A63D99072',
#       'type': 'user',
#       'avatar': {'id': '19820658',
#        'published_date': '2009-06-23T13:06:54-0400',
#        'helpful_votes': '0',
#        'is_blessed': False,
#        'uploaded_date': '2009-06-23T13:06:54-0400',
#        'images': {'small': {'url': 'https://media-cdn.tripadvisor.com/media/photo-l/01/2e/70/72/avatar054.jpg',
#          'width': '150',
#          'height': '150'},
#         'thumbnail': {'url': 'https://media-cdn.tripadvisor.com/media/photo-t/01/2e/70/72/avatar054.jpg',
#          'width': '50',
#          'height': '50'},
#         'large': {'url': 'https://media-cdn.tripadvisor.com/media/photo-s/01/2e/70/72/avatar054.jpg',
#          'width': '74',
#          'height': '74'},
#         'medium': {'url': 'https://media-cdn.tripadvisor.com/media/photo-f/01/2e/70/72/avatar054.jpg',
#          'width': '205',
#          'height': '205'}}}},
#      'helpful_votes': '0',
#      'is_blessed': False,
#      'uploaded_date': '2020-01-13T19:25:56-0500',
#      'images': {'small': {'url': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/98/50/e2/photo1jpg.jpg',
#        'width': '150',
#        'height': '150'},
#       'thumbnail': {'url': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/98/50/e2/photo1jpg.jpg',
#        'width': '50',
#        'height': '50'},
#       'original': {'url': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/98/50/e2/photo1jpg.jpg',
#        'width': '2048',
#        'height': '1536'},
#       'large': {'url': 'https://media-cdn.tripadvisor.com/media/photo-s/1a/98/50/e2/photo1jpg.jpg',
#        'width': '550',
#        'height': '413'},
#       'medium': {'url': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/98/50/e2/photo1jpg.jpg',
#        'width': '250',
#        'height': '188'}}},
#     {'id': '446189795',
#      'locations': [{'name': 'LegendSea Hotel',
#        'id': '8014024',
#        'web_url': 'https://www.tripadvisor.com/Hotel_Review-g293928-d8014024-Reviews-LegendSea_Hotel-Nha_Trang_Khanh_Hoa_Province.html',
#        'intent_url': 'tripadvisor:///Hotel_Review-g293928-d8014024-Reviews-LegendSea_Hotel-Nha_Trang_Khanh_Hoa_Province.html',
#        'parent_location_id': 293928}],
#      'published_date': '2020-01-13T19:25:56-0500',
#      'user': {'username': 'Nenenprado16',
#       'member_id': '0',
#       'user_id': '0297276CCFC9071B7805C00A63D99072',
#       'type': 'user',
#       'avatar': {'id': '19820658',
#        'published_date': '2009-06-23T13:06:54-0400',
#        'helpful_votes': '0',
#        'is_blessed': False,
#        'uploaded_date': '2009-06-23T13:06:54-0400',
#        'images': {'small': {'url': 'https://media-cdn.tripadvisor.com/media/photo-l/01/2e/70/72/avatar054.jpg',
#          'width': '150',
#          'height': '150'},
#         'thumbnail': {'url': 'https://media-cdn.tripadvisor.com/media/photo-t/01/2e/70/72/avatar054.jpg',
#          'width': '50',
#          'height': '50'},
#         'large': {'url': 'https://media-cdn.tripadvisor.com/media/photo-s/01/2e/70/72/avatar054.jpg',
#          'width': '74',
#          'height': '74'},
#         'medium': {'url': 'https://media-cdn.tripadvisor.com/media/photo-f/01/2e/70/72/avatar054.jpg',
#          'width': '205',
#          'height': '205'}}}},
#      'helpful_votes': '0',
#      'is_blessed': False,
#      'uploaded_date': '2020-01-13T19:25:56-0500',
#      'images': {'small': {'url': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/98/50/e3/photo2jpg.jpg',
#        'width': '150',
#        'height': '150'},
#       'thumbnail': {'url': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/98/50/e3/photo2jpg.jpg',
#        'width': '50',
#        'height': '50'},
#       'original': {'url': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/98/50/e3/photo2jpg.jpg',
#        'width': '2048',
#        'height': '1536'},
#       'large': {'url': 'https://media-cdn.tripadvisor.com/media/photo-s/1a/98/50/e3/photo2jpg.jpg',
#        'width': '550',
#        'height': '413'},
#       'medium': {'url': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/98/50/e3/photo2jpg.jpg',
#        'width': '250',
#        'height': '188'}}}]}],
#  'paging': {'results': '1', 'total_results': '376'}}

# %%
url = "https://tripadvisor1.p.rapidapi.com/attractions/get-details"
querystring = {"currency":"USD","lang":"en_US","location_id":"1451754", "limit":"1"}
headers = {
    'x-rapidapi-host': "tripadvisor1.p.rapidapi.com",
    'x-rapidapi-key': "c7f8c6b52emshd30579b9b931ccbp171746jsn2a2323a21126"
    }
response_3 = requests.request("GET", url, headers=headers, params=querystring)
response_3.json()
# Out:
# {'location_id': '1451754',
#  'name': 'Vinpearl Land Nha Trang',
#  'latitude': '12.20829',
#  'longitude': '109.2755',
#  'num_reviews': '7190',
#  'timezone': 'Asia/Ho_Chi_Minh',
#  'location_string': 'Nha Trang, Khanh Hoa Province',
#  'photo': {'images': {'small': {'width': '250',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-f/0d/09/88/44/lau-dai-phep-thu-t-vinpearl.jpg',
#     'height': '141'},
#    'thumbnail': {'width': '50',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-t/0d/09/88/44/lau-dai-phep-thu-t-vinpearl.jpg',
#     'height': '50'},
#    'original': {'width': '2000',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-o/0d/09/88/44/lau-dai-phep-thu-t-vinpearl.jpg',
#     'height': '1125'},
#    'large': {'width': '1024',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-w/0d/09/88/44/lau-dai-phep-thu-t-vinpearl.jpg',
#     'height': '576'},
#    'medium': {'width': '550',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-s/0d/09/88/44/lau-dai-phep-thu-t-vinpearl.jpg',
#     'height': '309'}},
#   'is_blessed': True,
#   'uploaded_date': '2016-09-21T03:55:31-0400',
#   'caption': 'Lâu đài phép thuật Vinpearl Land Nha Trang',
#   'id': '218728516',
#   'helpful_votes': '24',
#   'published_date': '2016-09-21T03:55:31-0400',
#   'user': {'user_id': None, 'member_id': '0', 'type': 'user'}},
#  'awards': [],
#  'location_subtype': 'none',
#  'doubleclick_zone': 'as.vietnam.khanh_hoa.nha_trang',
#  'preferred_map_engine': 'default',
#  'raw_ranking': '3.739790439605713',
#  'ranking_geo': 'Nha Trang',
#  'ranking_geo_id': '293928',
#  'ranking_position': '46',
#  'ranking_denominator': '457',
#  'ranking_category': 'attraction',
#  'ranking_subcategory': '#46 of 457 things to do in Nha Trang',
#  'subcategory_ranking': '#46 of 457 things to do in Nha Trang',
#  'ranking': '#46 of 457 things to do in Nha Trang',
#  'distance': None,
#  'distance_string': None,
#  'bearing': None,
#  'rating': '4.0',
#  'is_closed': False,
#  'open_now_text': 'Closed Now',
#  'is_long_closed': False,
#  'description': 'Designed to be an independent recreational area harmoniously linked with the five-star international Vinpearl Resort Nha Trang, Vinpearl Amusement Park is built on an area of approximately 200,000m2 and consists of many modern and unique large-scale facilities comparable to the leading entertainment parks across the region and the world.',
#  'web_url': 'https://www.tripadvisor.com/Attraction_Review-g293928-d1451754-Reviews-Vinpearl_Land_Nha_Trang-Nha_Trang_Khanh_Hoa_Province.html',
#  'write_review': 'https://www.tripadvisor.com/UserReview-g293928-d1451754-Vinpearl_Land_Nha_Trang-Nha_Trang_Khanh_Hoa_Province.html',
#  'ancestors': [{'subcategory': [{'key': 'city', 'name': 'City'}],
#    'name': 'Nha Trang',
#    'abbrv': None,
#    'location_id': '293928'},
#   {'subcategory': [{'key': 'province', 'name': 'Province'}],
#    'name': 'Khanh Hoa Province',
#    'abbrv': None,
#    'location_id': '1184689'},
#   {'subcategory': [{'key': 'country', 'name': 'Country'}],
#    'name': 'Vietnam',
#    'abbrv': None,
#    'location_id': '293921'}],
#  'category': {'key': 'attraction', 'name': 'Attraction'},
#  'subcategory': [{'key': '52', 'name': 'Water & Amusement Parks'}],
#  'parent_display_name': 'Nha Trang',
#  'is_jfy_enabled': False,
#  'nearest_metro_station': [],
#  'reviews': [{'title': 'Worst burger and customer service',
#    'rating': '1',
#    'published_date': '2020-01-15T01:56:00-05:00',
#    'summary': 'hair found in the burger, the environment is open and windy for the food served to be blown away. staff are not approachable and it gives this attraction a bad reputation. this should be reviewed...',
#    'author': 'VSmail1234',
#    'url': 'http://www.tripadvisor.com/ShowUserReviews-g293928-d1451754-r739245200-Vinpearl_Land_Nha_Trang-Nha_Trang_Khanh_Hoa_Province.html#review739245200',
#    'review_id': '739245200',
#    'machine_translated': False},
#   {'title': 'Wasted money',
#    'rating': '2',
#    'published_date': '2020-01-15T01:38:09-05:00',
#    'summary': '1 hour in the line to the cable car. \nNo, buying the ticket online will not save you any time or money. \nWhile price is similar, it takes them more time to locate your e-ticket in the system than...',
#    'author': 'Windride_Managment',
#    'url': 'http://www.tripadvisor.com/ShowUserReviews-g293928-d1451754-r739242835-Vinpearl_Land_Nha_Trang-Nha_Trang_Khanh_Hoa_Province.html#review739242835',
#    'review_id': '739242835',
#    'machine_translated': False},
#   {'title': 'A lovely day',
#    'rating': '5',
#    'published_date': '2020-01-11T02:27:48-05:00',
#    'summary': 'If you like a day full of action and activities this is the place to be!\nOnly one warning, you will be deadly tired when you back at home :))',
#    'author': 'anniehoang82',
#    'url': 'http://www.tripadvisor.com/ShowUserReviews-g293928-d1451754-r738425157-Vinpearl_Land_Nha_Trang-Nha_Trang_Khanh_Hoa_Province.html#review738425157',
#    'review_id': '738425157',
#    'machine_translated': False}],
#  'phone': '+84 1900 6677 ext. 1',
#  'website': 'http://nhatrang.vinpearlland.com/en/',
#  'email': 'we-care@vinpearlland.com',
#  'address_obj': {'street1': 'Hon Tre Island, Vinh Nguyen',
#   'street2': None,
#   'city': 'Nha Trang',
#   'state': None,
#   'country': 'Vietnam',
#   'postalcode': '650000'},
#  'address': 'Hon Tre Island, Vinh Nguyen, Nha Trang 650000 Vietnam',
#  'hours': {'week_ranges': [[{'open_time': 510, 'close_time': 1260}],
#    [{'open_time': 510, 'close_time': 1260}],
#    [{'open_time': 510, 'close_time': 1260}],
#    [{'open_time': 510, 'close_time': 1260}],
#    [{'open_time': 510, 'close_time': 1260}],
#    [{'open_time': 510, 'close_time': 1260}],
#    [{'open_time': 510, 'close_time': 1260}]],
#   'timezone': 'Asia/Ho_Chi_Minh'},
#  'local_name': 'Vinpearl Land Nha Trang',
#  'local_address': 'Đảo Hòn Tre, Vĩnh Nguyên, 650000',
#  'local_lang_code': 'vi',
#  'is_candidate_for_contact_info_suppression': False,
#  'subtype': [{'key': '118', 'name': 'Water Parks'},
#   {'key': '98', 'name': 'Theme Parks'}],
#  'recommended_visit_length': 'More than 3 hours',
#  'guide_featured_in_copy': 'As featured in 3 Days in Nha Trang and 4 other guides',
#  'shopping_type': 'none',
#  'is_product_review_eligible': False,
#  'photo_count': '8462',
#  'has_panoramic_photos': False,
#  'rating_histogram': {'count_1': '249',
#   'count_2': '300',
#   'count_3': '1032',
#   'count_4': '2033',
#   'count_5': '3576'}}

# %%
sample = response_3.json()
keys = list(sample.keys())
keys
# Out:
# ['location_id',
#  'name',
#  'latitude',
#  'longitude',
#  'num_reviews',
#  'timezone',
#  'location_string',
#  'photo',
#  'awards',
#  'location_subtype',
#  'doubleclick_zone',
#  'preferred_map_engine',
#  'raw_ranking',
#  'ranking_geo',
#  'ranking_geo_id',
#  'ranking_position',
#  'ranking_denominator',
#  'ranking_category',
#  'ranking_subcategory',
#  'subcategory_ranking',
#  'ranking',
#  'distance',
#  'distance_string',
#  'bearing',
#  'rating',
#  'is_closed',
#  'open_now_text',
#  'is_long_closed',
#  'description',
#  'web_url',
#  'write_review',
#  'ancestors',
#  'category',
#  'subcategory',
#  'parent_display_name',
#  'is_jfy_enabled',
#  'nearest_metro_station',
#  'reviews',
#  'phone',
#  'website',
#  'email',
#  'address_obj',
#  'address',
#  'hours',
#  'local_name',
#  'local_address',
#  'local_lang_code',
#  'is_candidate_for_contact_info_suppression',
#  'subtype',
#  'recommended_visit_length',
#  'guide_featured_in_copy',
#  'shopping_type',
#  'is_product_review_eligible',
#  'photo_count',
#  'has_panoramic_photos',
#  'rating_histogram']

# %%
sample['name']
# Out:
# 'Vinpearl Land Nha Trang'

# %%
sample['rating']
# Out:
# '4.0'

# %%
sample['ranking']
# Out:
# '#46 of 457 things to do in Nha Trang'

# %%
sample['raw_ranking']
# Out:
# '3.739790439605713'

# %%
sample['ranking_geo']
# Out:
# 'Nha Trang'

# %%
#same as "ranking"
sample['ranking_position']
# Out:
# '46'

# %%
#number of things to do in a particular place
sample['ranking_denominator']
# Out:
# '457'

# %%
sample['ranking_category']
# Out:
# 'attraction'

# %%
#same as "ranking"
sample['ranking_subcategory']
# Out:
# '#46 of 457 things to do in Nha Trang'

# %%
#same as "ranking"
sample['subcategory_ranking']
# Out:
# '#46 of 457 things to do in Nha Trang'

# %%
sample['num_reviews']
# Out:
# '7190'

# %%
#top 3 are returned
sample['reviews']
# Out:
# [{'title': 'Worst burger and customer service',
#   'rating': '1',
#   'published_date': '2020-01-15T01:56:00-05:00',
#   'summary': 'hair found in the burger, the environment is open and windy for the food served to be blown away. staff are not approachable and it gives this attraction a bad reputation. this should be reviewed...',
#   'author': 'VSmail1234',
#   'url': 'http://www.tripadvisor.com/ShowUserReviews-g293928-d1451754-r739245200-Vinpearl_Land_Nha_Trang-Nha_Trang_Khanh_Hoa_Province.html#review739245200',
#   'review_id': '739245200',
#   'machine_translated': False},
#  {'title': 'Wasted money',
#   'rating': '2',
#   'published_date': '2020-01-15T01:38:09-05:00',
#   'summary': '1 hour in the line to the cable car. \nNo, buying the ticket online will not save you any time or money. \nWhile price is similar, it takes them more time to locate your e-ticket in the system than...',
#   'author': 'Windride_Managment',
#   'url': 'http://www.tripadvisor.com/ShowUserReviews-g293928-d1451754-r739242835-Vinpearl_Land_Nha_Trang-Nha_Trang_Khanh_Hoa_Province.html#review739242835',
#   'review_id': '739242835',
#   'machine_translated': False},
#  {'title': 'A lovely day',
#   'rating': '5',
#   'published_date': '2020-01-11T02:27:48-05:00',
#   'summary': 'If you like a day full of action and activities this is the place to be!\nOnly one warning, you will be deadly tired when you back at home :))',
#   'author': 'anniehoang82',
#   'url': 'http://www.tripadvisor.com/ShowUserReviews-g293928-d1451754-r738425157-Vinpearl_Land_Nha_Trang-Nha_Trang_Khanh_Hoa_Province.html#review738425157',
#   'review_id': '738425157',
#   'machine_translated': False}]

# %%
sample['recommended_visit_length']
# Out:
# 'More than 3 hours'

# %%
sample['awards']
# Out:
# []

# %%
sample['category']
# Out:
# {'key': 'attraction', 'name': 'Attraction'}

# %%
sample['subcategory']
# Out:
# [{'key': '52', 'name': 'Water & Amusement Parks'}]

# %%
sample['nearest_metro_station']
# Out:
# []

# %%
#city, region, country data
sample['ancestors']
# Out:
# [{'subcategory': [{'key': 'city', 'name': 'City'}],
#   'name': 'Nha Trang',
#   'abbrv': None,
#   'location_id': '293928'},
#  {'subcategory': [{'key': 'province', 'name': 'Province'}],
#   'name': 'Khanh Hoa Province',
#   'abbrv': None,
#   'location_id': '1184689'},
#  {'subcategory': [{'key': 'country', 'name': 'Country'}],
#   'name': 'Vietnam',
#   'abbrv': None,
#   'location_id': '293921'}]

# %%
url = "https://tripadvisor1.p.rapidapi.com/locations/search"

querystring = {"limit":"1","sort":"relevance","offset":"0","lang":"en_US","currency":"USD","units":"mi","query":"United States"}

headers = {
    'x-rapidapi-host': "tripadvisor1.p.rapidapi.com",
    'x-rapidapi-key': "e1834ce5c0mshd672556248feb69p18ef70jsncbd79662d6cb"
    }

response_4 = requests.request("GET", url, headers=headers, params=querystring)

response_4.json()
# Out:
# {'data': [{'result_type': 'geos',
#    'result_object': {'location_id': '191',
#     'name': 'United States',
#     'latitude': '37.94097',
#     'longitude': '-95.39237',
#     'num_reviews': '87492134',
#     'timezone': 'America/Chicago',
#     'location_string': 'United States',
#     'photo': {'images': {'small': {'width': '150',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-l/15/33/f9/8d/united-states.jpg',
#        'height': '150'},
#       'thumbnail': {'width': '50',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-t/15/33/f9/8d/united-states.jpg',
#        'height': '50'},
#       'original': {'width': '4591',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-o/15/33/f9/8d/united-states.jpg',
#        'height': '897'},
#       'large': {'width': '550',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-s/15/33/f9/8d/united-states.jpg',
#        'height': '107'},
#       'medium': {'width': '250',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-f/15/33/f9/8d/united-states.jpg',
#        'height': '49'}},
#      'is_blessed': False,
#      'uploaded_date': '2018-10-30T14:12:35-0400',
#      'caption': '',
#      'id': '355727757',
#      'helpful_votes': '4',
#      'published_date': '2018-10-30T14:12:35-0400',
#      'user': None},
#     'awards': [],
#     'doubleclick_zone': 'na.united_states',
#     'preferred_map_engine': 'default',
#     'geo_type': 'broad',
#     'category_counts': {'attractions': {'activities': '101239',
#       'attractions': '71533',
#       'nightlife': '31384',
#       'shopping': '39202',
#       'total': '243358'},
#      'restaurants': {'total': '970548'},
#      'accommodations': {'hotels': '58485',
#       'bbs_inns': '22432',
#       'others': '24969',
#       'total': '105886'},
#      'neighborhoods': '0',
#      'airports': '0'},
#     'nearby_attractions': [],
#     'description': '',
#     'web_url': '',
#     'ancestors': [],
#     'category': {'key': 'geographic', 'name': 'Geographic'},
#     'subcategory': [{'key': 'country', 'name': 'Country'}],
#     'is_jfy_enabled': False,
#     'nearest_metro_station': [],
#     'geo_description': 'Spanning 2,800 miles (4,506 kilometers) from east to west, the US is a vast patchwork of landscapes and metropolises. From Arizona’s red-rocked canyons and California’s coastal beaches to New York’s big city and Virginia’s storied past, it covers any topic any traveler could want or need.',
#     'has_restaurant_coverpage': False,
#     'has_attraction_coverpage': False,
#     'has_curated_shopping_list': False},
#    'scope': 'local',
#    'is_top_result': True}],
#  'metadata': {'scope': 'local'},
#  'sort': [{'filter_key': 'relevance',
#    'label': 'Relevance',
#    'locale_independent_label': 'relevance',
#    'selected': True},
#   {'filter_key': 'distance',
#    'label': 'Distance',
#    'locale_independent_label': 'distance',
#    'selected': False}],
#  'partial_content': True,
#  'tracking': {'search_id': 'B971D675916974269F4C8D10E0FF6ADC1579214543864'},
#  'paging': {'results': '1', 'total_results': '2503832'}}

# %%
url = "https://tripadvisor1.p.rapidapi.com/attractions/get-details"
querystring = {"currency":"USD","lang":"en_US","location_id":"191", "limit":"1"}
headers = {
    'x-rapidapi-host': "tripadvisor1.p.rapidapi.com",
    'x-rapidapi-key': "c7f8c6b52emshd30579b9b931ccbp171746jsn2a2323a21126"
    }
response_5 = requests.request("GET", url, headers=headers, params=querystring)
response_5.json()
# Out:
# {'location_id': '191',
#  'name': 'United States',
#  'latitude': '37.94097',
#  'longitude': '-95.39237',
#  'num_reviews': '87492134',
#  'timezone': 'America/Chicago',
#  'location_string': 'United States',
#  'photo': {'images': {'small': {'width': '150',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-l/15/33/f9/8d/united-states.jpg',
#     'height': '150'},
#    'thumbnail': {'width': '50',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-t/15/33/f9/8d/united-states.jpg',
#     'height': '50'},
#    'original': {'width': '4591',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-o/15/33/f9/8d/united-states.jpg',
#     'height': '897'},
#    'large': {'width': '550',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-s/15/33/f9/8d/united-states.jpg',
#     'height': '107'},
#    'medium': {'width': '250',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-f/15/33/f9/8d/united-states.jpg',
#     'height': '49'}},
#   'is_blessed': False,
#   'uploaded_date': '2018-10-30T14:12:35-0400',
#   'caption': '',
#   'id': '355727757',
#   'helpful_votes': '4',
#   'published_date': '2018-10-30T14:12:35-0400',
#   'user': None},
#  'awards': [],
#  'doubleclick_zone': 'na.united_states',
#  'preferred_map_engine': 'default',
#  'geo_type': 'broad',
#  'category_counts': {'attractions': {'activities': '101239',
#    'attractions': '71533',
#    'nightlife': '31384',
#    'shopping': '39202',
#    'total': '243358'},
#   'restaurants': {'total': '970548'},
#   'accommodations': {'hotels': '58485',
#    'bbs_inns': '22432',
#    'others': '24969',
#    'total': '105886'},
#   'neighborhoods': '0',
#   'airports': '0',
#   'attraction_products': '21283'},
#  'nearby_attractions': [],
#  'description': 'Spanning 2,800 miles (4,506 kilometers) from east to west, the US is a vast patchwork of landscapes and metropolises. From Arizona’s red-rocked canyons and California’s coastal beaches to New York’s big city and Virginia’s storied past, it covers any topic any traveler could want or need.',
#  'web_url': 'https://www.tripadvisor.com/Tourism-g191-United_States-Vacations.html',
#  'write_review': 'https://www.tripadvisor.com/UserReview-g191-United_States.html',
#  'ancestors': [],
#  'category': {'key': 'geographic', 'name': 'Geographic'},
#  'subcategory': [{'key': 'country', 'name': 'Country'}],
#  'parent_display_name': 'North America',
#  'is_jfy_enabled': False,
#  'nearest_metro_station': [],
#  'geo_description': 'Spanning 2,800 miles (4,506 kilometers) from east to west, the US is a vast patchwork of landscapes and metropolises. From Arizona’s red-rocked canyons and California’s coastal beaches to New York’s big city and Virginia’s storied past, it covers any topic any traveler could want or need.',
#  'has_restaurant_coverpage': False,
#  'has_attraction_coverpage': True,
#  'has_curated_shopping_list': False,
#  'has_panoramic_photos': False}

# %%
url = "https://tripadvisor1.p.rapidapi.com/locations/search"

querystring = {"limit":"2","sort":"relevance","offset":"0","lang":"en_US","currency":"USD","units":"mi","query":"United States"}

headers = {
    'x-rapidapi-host': "tripadvisor1.p.rapidapi.com",
    'x-rapidapi-key': "e1834ce5c0mshd672556248feb69p18ef70jsncbd79662d6cb"
    }

response_6 = requests.request("GET", url, headers=headers, params=querystring)
response_6.json()
# Out:
# {'data': [{'result_type': 'geos',
#    'result_object': {'location_id': '191',
#     'name': 'United States',
#     'latitude': '37.94097',
#     'longitude': '-95.39237',
#     'num_reviews': '87492134',
#     'timezone': 'America/Chicago',
#     'location_string': 'United States',
#     'photo': {'images': {'small': {'width': '150',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-l/15/33/f9/8d/united-states.jpg',
#        'height': '150'},
#       'thumbnail': {'width': '50',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-t/15/33/f9/8d/united-states.jpg',
#        'height': '50'},
#       'original': {'width': '4591',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-o/15/33/f9/8d/united-states.jpg',
#        'height': '897'},
#       'large': {'width': '550',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-s/15/33/f9/8d/united-states.jpg',
#        'height': '107'},
#       'medium': {'width': '250',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-f/15/33/f9/8d/united-states.jpg',
#        'height': '49'}},
#      'is_blessed': False,
#      'uploaded_date': '2018-10-30T14:12:35-0400',
#      'caption': '',
#      'id': '355727757',
#      'helpful_votes': '4',
#      'published_date': '2018-10-30T14:12:35-0400',
#      'user': None},
#     'awards': [],
#     'doubleclick_zone': 'na.united_states',
#     'preferred_map_engine': 'default',
#     'geo_type': 'broad',
#     'category_counts': {'attractions': {'activities': '101239',
#       'attractions': '71533',
#       'nightlife': '31384',
#       'shopping': '39202',
#       'total': '243358'},
#      'restaurants': {'total': '970548'},
#      'accommodations': {'hotels': '58485',
#       'bbs_inns': '22432',
#       'others': '24969',
#       'total': '105886'},
#      'neighborhoods': '0',
#      'airports': '0'},
#     'nearby_attractions': [],
#     'description': '',
#     'web_url': '',
#     'ancestors': [],
#     'category': {'key': 'geographic', 'name': 'Geographic'},
#     'subcategory': [{'key': 'country', 'name': 'Country'}],
#     'is_jfy_enabled': False,
#     'nearest_metro_station': [],
#     'geo_description': 'Spanning 2,800 miles (4,506 kilometers) from east to west, the US is a vast patchwork of landscapes and metropolises. From Arizona’s red-rocked canyons and California’s coastal beaches to New York’s big city and Virginia’s storied past, it covers any topic any traveler could want or need.',
#     'has_restaurant_coverpage': False,
#     'has_attraction_coverpage': False,
#     'has_curated_shopping_list': False},
#    'scope': 'local',
#    'is_top_result': True},
#   {'result_type': 'things_to_do',
#    'result_object': {'location_id': '103441',
#     'name': 'United States Holocaust Memorial Museum',
#     'latitude': '38.88678',
#     'longitude': '-77.03256',
#     'num_reviews': '11095',
#     'timezone': 'America/New_York',
#     'location_string': 'Washington DC, District of Columbia',
#     'photo': {'images': {'small': {'width': '250',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-f/13/bd/86/dd/1200px-united-states.jpg',
#        'height': '143'},
#       'thumbnail': {'width': '50',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-t/13/bd/86/dd/1200px-united-states.jpg',
#        'height': '50'},
#       'original': {'width': '1200',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-o/13/bd/86/dd/1200px-united-states.jpg',
#        'height': '686'},
#       'large': {'width': '1024',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-w/13/bd/86/dd/1200px-united-states.jpg',
#        'height': '585'},
#       'medium': {'width': '550',
#        'url': 'https://media-cdn.tripadvisor.com/media/photo-s/13/bd/86/dd/1200px-united-states.jpg',
#        'height': '314'}},
#      'is_blessed': False,
#      'uploaded_date': '2018-07-17T17:48:16-0400',
#      'caption': '',
#      'id': '331187933',
#      'helpful_votes': '1',
#      'published_date': '2018-07-17T17:48:16-0400',
#      'user': {'user_id': None, 'member_id': '0', 'type': 'user'}},
#     'awards': [],
#     'location_subtype': 'none',
#     'preferred_map_engine': 'default',
#     'distance': None,
#     'distance_string': None,
#     'bearing': None,
#     'rating': '4.5',
#     'is_closed': False,
#     'open_now_text': 'Closed Now',
#     'is_long_closed': False,
#     'description': '',
#     'web_url': '',
#     'ancestors': [{'subcategory': [{'key': 'city', 'name': 'City'}],
#       'name': 'Washington DC',
#       'abbrv': None,
#       'location_id': '28970'},
#      {'subcategory': [{'key': 'state', 'name': 'State'}],
#       'name': 'District of Columbia',
#       'abbrv': 'DC',
#       'location_id': '28969'},
#      {'subcategory': [{'key': 'country', 'name': 'Country'}],
#       'name': 'United States',
#       'abbrv': None,
#       'location_id': '191'}],
#     'category': {'key': 'attraction', 'name': 'Attraction'},
#     'subcategory': [{'key': '49', 'name': 'Museums'}],
#     'is_jfy_enabled': False,
#     'nearest_metro_station': [],
#     'address_obj': {'street1': '100 Raoul Wallenberg Plaza SW',
#      'street2': None,
#      'city': 'Washington DC',
#      'state': 'DC',
#      'country': 'United States',
#      'postalcode': '20024-2126'},
#     'address': '100 Raoul Wallenberg Plaza SW, Washington DC, DC 20024-2126',
#     'is_candidate_for_contact_info_suppression': False,
#     'shopping_type': 'none'},
#    'search_explanations': {'mentioned_by_travelers': 'matches 117 reviews'},
#    'review_snippet': {'snippet': 'Before beginning the new year, we were fortunate to visit the United States',
#     'spans': [{'start_index': 62, 'end_index': 68},
#      {'start_index': 69, 'end_index': 75}],
#     'review_id': '736783452'},
#    'scope': 'local'}],
#  'metadata': {'scope': 'local'},
#  'sort': [{'filter_key': 'relevance',
#    'label': 'Relevance',
#    'locale_independent_label': 'relevance',
#    'selected': True},
#   {'filter_key': 'distance',
#    'label': 'Distance',
#    'locale_independent_label': 'distance',
#    'selected': False}],
#  'partial_content': True,
#  'tracking': {'search_id': '0D7A42CC4CF2546AD187D9BEFAB638CF1579215147572'},
#  'paging': {'results': '2', 'total_results': '2592303'}}

# %%
sample_2 = response_6.json()
len(sample_2)
# Out:
# 6

# %%
sample_2['data'][0]['result_object']
# Out:
# {'location_id': '191',
#  'name': 'United States',
#  'latitude': '37.94097',
#  'longitude': '-95.39237',
#  'num_reviews': '87492134',
#  'timezone': 'America/Chicago',
#  'location_string': 'United States',
#  'photo': {'images': {'small': {'width': '150',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-l/15/33/f9/8d/united-states.jpg',
#     'height': '150'},
#    'thumbnail': {'width': '50',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-t/15/33/f9/8d/united-states.jpg',
#     'height': '50'},
#    'original': {'width': '4591',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-o/15/33/f9/8d/united-states.jpg',
#     'height': '897'},
#    'large': {'width': '550',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-s/15/33/f9/8d/united-states.jpg',
#     'height': '107'},
#    'medium': {'width': '250',
#     'url': 'https://media-cdn.tripadvisor.com/media/photo-f/15/33/f9/8d/united-states.jpg',
#     'height': '49'}},
#   'is_blessed': False,
#   'uploaded_date': '2018-10-30T14:12:35-0400',
#   'caption': '',
#   'id': '355727757',
#   'helpful_votes': '4',
#   'published_date': '2018-10-30T14:12:35-0400',
#   'user': None},
#  'awards': [],
#  'doubleclick_zone': 'na.united_states',
#  'preferred_map_engine': 'default',
#  'geo_type': 'broad',
#  'category_counts': {'attractions': {'activities': '101239',
#    'attractions': '71533',
#    'nightlife': '31384',
#    'shopping': '39202',
#    'total': '243358'},
#   'restaurants': {'total': '970548'},
#   'accommodations': {'hotels': '58485',
#    'bbs_inns': '22432',
#    'others': '24969',
#    'total': '105886'},
#   'neighborhoods': '0',
#   'airports': '0'},
#  'nearby_attractions': [],
#  'description': '',
#  'web_url': '',
#  'ancestors': [],
#  'category': {'key': 'geographic', 'name': 'Geographic'},
#  'subcategory': [{'key': 'country', 'name': 'Country'}],
#  'is_jfy_enabled': False,
#  'nearest_metro_station': [],
#  'geo_description': 'Spanning 2,800 miles (4,506 kilometers) from east to west, the US is a vast patchwork of landscapes and metropolises. From Arizona’s red-rocked canyons and California’s coastal beaches to New York’s big city and Virginia’s storied past, it covers any topic any traveler could want or need.',
#  'has_restaurant_coverpage': False,
#  'has_attraction_coverpage': False,
#  'has_curated_shopping_list': False}
