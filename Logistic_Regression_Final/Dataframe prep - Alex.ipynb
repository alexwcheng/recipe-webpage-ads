# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import json
# %matplotlib inline

# %%
with open("../Data/top_1000_recipes_info.json") as datafile:
  data = json.load(datafile)

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %%
len(data)
# Out:
# 10

# %%
type(data[0][99]['analyzedInstructions'])
# Out:
# list

# %%
for rec_list in data:
    for recipe in rec_list:
        # Add clean nutrition column
        nutrients = []
        nutrient_amts = []
        for index, val in enumerate(recipe['nutrition']['nutrients']):
            nutrient_name = recipe['nutrition']['nutrients'][index]['title']
            nutrients.append(nutrient_name)
            nutrient_amt = recipe['nutrition']['nutrients'][index]['amount']
            nutrient_amts.append(nutrient_amt)
        recipe['nutrition_info'] = dict(zip(nutrients, nutrient_amts))

        # Add num ingredients
        recipe['num_ingredients'] = len(recipe['extendedIngredients'])

        # Add list ingredients and types
        recipe['extendedIngredients'] = []
        ing_type_list = []
        recipe['ingredient_types'] = {}
        for index, val in enumerate(recipe['extendedIngredients']):
            if type(recipe['extendedIngredients']) == 'list':
                ing_name = recipe['extendedIngredients'][index]['name']
                ing_list.append(ing_name)
                ing_type = recipe['extendedIngredients'][index]['aisle']
        
                ing_type_list.append(ing_type)
                ing_type_counts = dict(zip(Counter(ing_type_list).keys(), Counter(ing_type_list).values()))
            recipe['ingredient_types'] = ing_type_counts
            recipe['extendedIngredients'] = ing_list

        # Num words in instructions
        recipe['num_instruction_words'] = 0
        if type(recipe['instructions']) == str:
            num_words = len(recipe['instructions'].split())
            recipe['num_instruction_words'] = num_words

        # Num steps
        recipe['num_steps'] = 0
        if type(recipe['analyzedInstructions']) == list:
            if type(recipe['analyzedInstructions'][0]['steps']) == list:
                recipe['num_steps'] = len(recipe['analyzedInstructions'][0]['steps'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-4f5fd36cad03> in <module>
#      38         recipe['num_steps'] = 0
#      39         if type(recipe['analyzedInstructions']) == list:
# ---> 40             if type(recipe['analyzedInstructions'][0]['steps']) == list:
#      41                 recipe['num_steps'] = len(recipe['analyzedInstructions'][0]['steps'])
#
# IndexError: list index out of range

# %%
columns = ['vegetarian', 'vegan', 'glutenFree', 'dairyFree', 'veryHealthy', 'cheap', 
           'veryPopular', 'sustainable', 'ketogenic', 'whole30', 'aggregateLikes', 
           'spoonacularScore', 'healthScore', 'pricePerServing', 'extendedIngredients', 
           'id', 'title', 'readyInMinutes', 'servings', 'nutrition', 'cuisines', 'dishTypes',
           'diets', 'occasions', 'winePairing', 'instructions', 'analyzedInstructions', 
           'preparationMinutes', 'cookingMinutes', 'num_steps', 'nutrition_info', 'num_instruction_words',
           'ingredient_types', 'num_ingredients']

df = pd.DataFrame(columns = columns)
for ind_10, val in enumerate(data):
    df_new = pd.DataFrame(data[ind_10])
    df = pd.concat([df, df_new])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
df.head()
# Out:
#   aggregateLikes                               analyzedInstructions  cheap  cookingMinutes             creditsText cuisines dairyFree                                              diets                                dishTypes extendedIngredients gaps glutenFree  healthScore      id                                              image imageType ingredient_types                                       instructions ketogenic license lowFodmap num_ingredients num_instruction_words num_steps                                          nutrition                                     nutrition_info occasions  preparationMinutes  pricePerServing readyInMinutes servings              sourceName                                          sourceUrl  spoonacularScore                               spoonacularSourceUrl sustainable                                           title  vegan vegetarian veryHealthy veryPopular  weightWatcherSmartPoints whole30                                        winePairing
# 0          50078  [{'name': '', 'steps': [{'number': 1, 'step': ...  False            25.0          Fat Free Vegan       []      True  [gluten free, dairy free, lacto ovo vegetarian...                              [side dish]                  []   no       True        100.0  592479  https://spoonacular.com/recipeImages/592479-55...       jpg               {}  Instructions  Heat a saucepan. Add the rinsed ...     False     NaN     False              15                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 242.6, 'Fat': 7.38, 'Saturated Fa...        []                25.0           101.23             50        6          Fat Free Vegan  http://blog.fatfreevegan.com/2013/06/kale-and-...             100.0  https://spoonacular.com/kale-and-quinoa-salad-...       False          Kale and Quinoa Salad with Black Beans   True       True        True        True                       6.0   False                                                 {}
# 1          67131  [{'name': '', 'steps': [{'number': 1, 'step': ...  False            10.0  Two Peas and Their Pod       []      True          [dairy free, lacto ovo vegetarian, vegan]  [lunch, main course, main dish, dinner]                  []   no      False        100.0  547775  https://spoonacular.com/recipeImages/547775-55...       jpg               {}  1. Bring water to a boil in a medium sized pot...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 484.43, 'Fat': 16.17, 'Saturated ...        []                 5.0           171.39             15        2  Two Peas and Their Pod  http://www.twopeasandtheirpod.com/creamy-avoca...             100.0  https://spoonacular.com/creamy-avocado-pasta-5...       False                            Creamy Avocado Pasta   True       True        True        True                      13.0   False  {'pairedWines': [], 'pairingText': 'No one win...
# 2         142071  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             5.0  Two Peas and Their Pod       []      True                 [dairy free, lacto ovo vegetarian]                              [side dish]                  []   no      False         95.0  818941  https://spoonacular.com/recipeImages/818941-55...       jpg               {}  Spray a small skillet with non-stick cooking s...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 277.24, 'Fat': 15.9, 'Saturated F...        []                 5.0           160.46             10        1  Two Peas and Their Pod  http://www.twopeasandtheirpod.com/avocado-toas...             100.0  https://spoonacular.com/avocado-toast-with-egg...       False  Avocado Toast with Eggs, Spinach, and Tomatoes  False       True        True        True                       7.0   False  {'pairedWines': [], 'pairingText': '', 'produc...
# 3           7119  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             5.0           Oh My Veggies       []      True  [gluten free, dairy free, lacto ovo vegetarian...                              [side dish]                  []   no       True        100.0  495111  https://spoonacular.com/recipeImages/495111-55...       jpg               {}  Heat sesame oil in a large skillet or wok over...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 72.07, 'Fat': 3.56, 'Saturated Fa...        []                10.0            51.22             15        4           Oh My Veggies  http://ohmyveggies.com/recipe-citrus-sesame-kale/             100.0  https://spoonacular.com/citrus-sesame-kale-495111       False                              Citrus Sesame Kale   True       True        True        True                       1.0   False                                                 {}
# 4         231494  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             0.0               Food Babe       []     False                              [gluten free, primal]                                  [salad]                  []   no       True         96.0  689502  https://spoonacular.com/recipeImages/689502-55...       jpg               {}  In a food processor, process kale into small c...     False     NaN     False               8                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 441.93, 'Fat': 33.36, 'Saturated ...        []                10.0           279.17             10        2               Food Babe  http://foodbabe.com/2013/05/08/melt-in-your-mo...             100.0  https://spoonacular.com/melt-in-your-mouth-kal...       False                   Melt In Your Mouth Kale Salad  False      False        True        True                      11.0   False                                                 {}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 44 columns):
# aggregateLikes              1000 non-null object
# analyzedInstructions        1000 non-null object
# cheap                       1000 non-null object
# cookingMinutes              719 non-null float64
# creditsText                 976 non-null object
# cuisines                    1000 non-null object
# dairyFree                   1000 non-null object
# diets                       1000 non-null object
# dishTypes                   1000 non-null object
# extendedIngredients         1000 non-null object
# gaps                        1000 non-null object
# glutenFree                  1000 non-null object
# healthScore                 1000 non-null float64
# id                          1000 non-null object
# image                       995 non-null object
# imageType                   995 non-null object
# ingredient_types            1000 non-null object
# instructions                950 non-null object
# ketogenic                   1000 non-null object
# license                     1 non-null object
# lowFodmap                   1000 non-null object
# num_ingredients             1000 non-null object
# num_instruction_words       1000 non-null object
# num_steps                   1000 non-null object
# nutrition                   1000 non-null object
# nutrition_info              1000 non-null object
# occasions                   1000 non-null object
# preparationMinutes          719 non-null float64
# pricePerServing             1000 non-null float64
# readyInMinutes              1000 non-null object
# servings                    1000 non-null object
# sourceName                  976 non-null object
# sourceUrl                   1000 non-null object
# spoonacularScore            1000 non-null float64
# spoonacularSourceUrl        1000 non-null object
# sustainable                 1000 non-null object
# title                       1000 non-null object
# vegan                       1000 non-null object
# vegetarian                  1000 non-null object
# veryHealthy                 1000 non-null object
# veryPopular                 1000 non-null object
# weightWatcherSmartPoints    1000 non-null float64
# whole30                     1000 non-null object
# winePairing                 1000 non-null object
# dtypes: float64(6), object(38)
# memory usage: 351.6+ KB

# %%
df.reset_index(drop = True, inplace= True)

# %%
df.head()
# Out:
#   aggregateLikes                               analyzedInstructions  cheap  cookingMinutes             creditsText cuisines dairyFree                                              diets                                dishTypes extendedIngredients gaps glutenFree  healthScore      id                                              image imageType ingredient_types                                       instructions ketogenic license lowFodmap num_ingredients num_instruction_words num_steps                                          nutrition                                     nutrition_info occasions  preparationMinutes  pricePerServing readyInMinutes servings              sourceName                                          sourceUrl  spoonacularScore                               spoonacularSourceUrl sustainable                                           title  vegan vegetarian veryHealthy veryPopular  weightWatcherSmartPoints whole30                                        winePairing
# 0          50078  [{'name': '', 'steps': [{'number': 1, 'step': ...  False            25.0          Fat Free Vegan       []      True  [gluten free, dairy free, lacto ovo vegetarian...                              [side dish]                  []   no       True        100.0  592479  https://spoonacular.com/recipeImages/592479-55...       jpg               {}  Instructions  Heat a saucepan. Add the rinsed ...     False     NaN     False              15                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 242.6, 'Fat': 7.38, 'Saturated Fa...        []                25.0           101.23             50        6          Fat Free Vegan  http://blog.fatfreevegan.com/2013/06/kale-and-...             100.0  https://spoonacular.com/kale-and-quinoa-salad-...       False          Kale and Quinoa Salad with Black Beans   True       True        True        True                       6.0   False                                                 {}
# 1          67131  [{'name': '', 'steps': [{'number': 1, 'step': ...  False            10.0  Two Peas and Their Pod       []      True          [dairy free, lacto ovo vegetarian, vegan]  [lunch, main course, main dish, dinner]                  []   no      False        100.0  547775  https://spoonacular.com/recipeImages/547775-55...       jpg               {}  1. Bring water to a boil in a medium sized pot...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 484.43, 'Fat': 16.17, 'Saturated ...        []                 5.0           171.39             15        2  Two Peas and Their Pod  http://www.twopeasandtheirpod.com/creamy-avoca...             100.0  https://spoonacular.com/creamy-avocado-pasta-5...       False                            Creamy Avocado Pasta   True       True        True        True                      13.0   False  {'pairedWines': [], 'pairingText': 'No one win...
# 2         142071  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             5.0  Two Peas and Their Pod       []      True                 [dairy free, lacto ovo vegetarian]                              [side dish]                  []   no      False         95.0  818941  https://spoonacular.com/recipeImages/818941-55...       jpg               {}  Spray a small skillet with non-stick cooking s...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 277.24, 'Fat': 15.9, 'Saturated F...        []                 5.0           160.46             10        1  Two Peas and Their Pod  http://www.twopeasandtheirpod.com/avocado-toas...             100.0  https://spoonacular.com/avocado-toast-with-egg...       False  Avocado Toast with Eggs, Spinach, and Tomatoes  False       True        True        True                       7.0   False  {'pairedWines': [], 'pairingText': '', 'produc...
# 3           7119  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             5.0           Oh My Veggies       []      True  [gluten free, dairy free, lacto ovo vegetarian...                              [side dish]                  []   no       True        100.0  495111  https://spoonacular.com/recipeImages/495111-55...       jpg               {}  Heat sesame oil in a large skillet or wok over...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 72.07, 'Fat': 3.56, 'Saturated Fa...        []                10.0            51.22             15        4           Oh My Veggies  http://ohmyveggies.com/recipe-citrus-sesame-kale/             100.0  https://spoonacular.com/citrus-sesame-kale-495111       False                              Citrus Sesame Kale   True       True        True        True                       1.0   False                                                 {}
# 4         231494  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             0.0               Food Babe       []     False                              [gluten free, primal]                                  [salad]                  []   no       True         96.0  689502  https://spoonacular.com/recipeImages/689502-55...       jpg               {}  In a food processor, process kale into small c...     False     NaN     False               8                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 441.93, 'Fat': 33.36, 'Saturated ...        []                10.0           279.17             10        2               Food Babe  http://foodbabe.com/2013/05/08/melt-in-your-mo...             100.0  https://spoonacular.com/melt-in-your-mouth-kal...       False                   Melt In Your Mouth Kale Salad  False      False        True        True                      11.0   False                                                 {}

# %%
#want to index through each one of these to get out the values into a new list each
df['nutrition_info'][1]['Vitamin K']
# Out:
# 31.03

# %%
n = list(df['nutrition_info'][0].keys())
n
# Out:
# ['Calories',
#  'Fat',
#  'Saturated Fat',
#  'Carbohydrates',
#  'Sugar',
#  'Cholesterol',
#  'Sodium',
#  'Protein',
#  'Vitamin K',
#  'Vitamin A',
#  'Vitamin C',
#  'Manganese',
#  'Folate',
#  'Fiber',
#  'Copper',
#  'Magnesium',
#  'Phosphorus',
#  'Vitamin B6',
#  'Potassium',
#  'Vitamin B1',
#  'Iron',
#  'Vitamin B2',
#  'Vitamin E',
#  'Zinc',
#  'Vitamin B5',
#  'Vitamin B3',
#  'Calcium',
#  'Selenium']

# %%
numbers = list(range(0,1000))

Calories = []
Fat = []
Saturated_Fat = []
Carbohydrates = []
Sugar = []
Cholesterol = []
Sodium = []
Protein = []
Vitamin_K = []
Vitamin_A = []
Vitamin_C = []
Manganese = []
Folate = []
Fiber = []
Copper = []
Magnesium = []
Phosphorus = []
Vitamin_B6 = []
Potassium = []
Vitamin_B1 = []
Iron = []
Vitamin_B2 = []
Vitamin_E = []
Zinc = []
Vitamin_B5 = []
Vitamin_B3 = []
Calcium = []
Selenium = []

for x in numbers:
    if 'Calories' in df['nutrition_info'][x]:
        Calories.append(df['nutrition_info'][x]['Calories'])
    else:
        Calories.append(0)
        
for x in numbers:
    if 'Fat' in df['nutrition_info'][x]:
        Fat.append(df['nutrition_info'][x]['Fat'])
    else:
        Fat.append(0)
    
for x in numbers:
    if 'Saturated Fat' in df['nutrition_info'][x]:
        Saturated_Fat.append(df['nutrition_info'][x]['Saturated Fat'])
    else:
        Saturated_Fat.append(0)
    
for x in numbers:
    if 'Carbohydrates' in df['nutrition_info'][x]:
        Carbohydrates.append(df['nutrition_info'][x]['Carbohydrates'])
    else:
        Carbohydrates.append(0)
    
for x in numbers:
    if 'Sugar' in df['nutrition_info'][x]:
        Sugar.append(df['nutrition_info'][x]['Sugar'])
    else:
        Sugar.append(0)
    
for x in numbers:
    if 'Cholesterol' in df['nutrition_info'][x]:
        Cholesterol.append(df['nutrition_info'][x]['Cholesterol'])
    else:
        Cholesterol.append(0)
        
for x in numbers:
    if 'Sodium' in df['nutrition_info'][x]:
        Sodium.append(df['nutrition_info'][x]['Sodium'])
    else:
        Sodium.append(0)
    
for x in numbers:
    if 'Protein' in df['nutrition_info'][x]:
        Protein.append(df['nutrition_info'][x]['Protein'])
    else:
        Protein.append(0)
    
for x in numbers:
    if 'Vitamin K' in df['nutrition_info'][x]:
        Vitamin_K.append(df['nutrition_info'][x]['Vitamin K'])
    else:
        Vitamin_K.append(0)
    
for x in numbers:
    if 'Vitamin A' in df['nutrition_info'][x]:
        Vitamin_A.append(df['nutrition_info'][x]['Vitamin A'])
    else:
        Vitamin_A.append(0)
    
for x in numbers:
    if 'Vitamin C' in df['nutrition_info'][x]:
        Vitamin_C.append(df['nutrition_info'][x]['Vitamin C'])
    else:
        Vitamin_C.append(0)
    
for x in numbers:
    if 'Manganese' in df['nutrition_info'][x]:
        Manganese.append(df['nutrition_info'][x]['Manganese'])
    else:
        Manganese.append(0)
    
for x in numbers:
    if 'Folate' in df['nutrition_info'][x]:
        Folate.append(df['nutrition_info'][x]['Folate'])
    else:
        Folate.append(0)
    
for x in numbers:
    if 'Fiber' in df['nutrition_info'][x]:
        Fiber.append(df['nutrition_info'][x]['Fiber'])
    else:
        Fiber.append(0)
    
for x in numbers:
    if 'Copper' in df['nutrition_info'][x]:
        Copper.append(df['nutrition_info'][x]['Copper'])
    else:
        Copper.append(0)
    
for x in numbers:
    if 'Magnesium' in df['nutrition_info'][x]:
        Magnesium.append(df['nutrition_info'][x]['Magnesium'])
    else:
        Magnesium.append(0)
    
for x in numbers:
    if 'Phosphorus' in df['nutrition_info'][x]:
        Phosphorus.append(df['nutrition_info'][x]['Phosphorus'])
    else:
        Phosphorus.append(0)
    
for x in numbers:
    if 'Vitamin B6' in df['nutrition_info'][x]:
        Vitamin_B6.append(df['nutrition_info'][x]['Vitamin B6'])
    else:
        Vitamin_B6.append(0)
    
for x in numbers:
    if 'Potassium' in df['nutrition_info'][x]:
        Potassium.append(df['nutrition_info'][x]['Potassium'])
    else:
        Potassium.append(0)
    
for x in numbers:
    if 'Vitamin B1' in df['nutrition_info'][x]:
        Vitamin_B1.append(df['nutrition_info'][x]['Vitamin B1'])
    else:
        Vitamin_B1.append(0)
    
for x in numbers:
    if 'Iron' in df['nutrition_info'][x]:
        Iron.append(df['nutrition_info'][x]['Iron'])
    else:
        Iron.append(0)
        
for x in numbers:
    if 'Vitamin B2' in df['nutrition_info'][x]:
        Vitamin_B2.append(df['nutrition_info'][x]['Vitamin B2'])
    else:
        Vitamin_B2.append(0)
    
for x in numbers:
    if 'Vitamin E' in df['nutrition_info'][x]:
        Vitamin_E.append(df['nutrition_info'][x]['Vitamin E'])
    else:
        Vitamin_E.append(0)
    
for x in numbers:
    if 'Zinc' in df['nutrition_info'][x]:
        Zinc.append(df['nutrition_info'][x]['Zinc'])
    else:
        Zinc.append(0)
    
for x in numbers:
    if 'Vitamin B5' in df['nutrition_info'][x]:
        Vitamin_B5.append(df['nutrition_info'][x]['Vitamin B5'])
    else:
        Vitamin_B5.append(0)
    
for x in numbers:
    if 'Vitamin B3' in df['nutrition_info'][x]:
        Vitamin_B3.append(df['nutrition_info'][x]['Vitamin B3'])
    else:
        Vitamin_B3.append(0)
    
for x in numbers:
    if 'Calcium' in df['nutrition_info'][x]:
        Calcium.append(df['nutrition_info'][x]['Calcium'])
    else:
        Calcium.append(0)
    
for x in numbers:
    if 'Selenium' in df['nutrition_info'][x]:
        Selenium.append(df['nutrition_info'][x]['Selenium'])
    else:
        Selenium.append(0)

# %%
df['Calories'] = Calories
df['Fat'] = Fat
df['Saturated_Fat'] = Saturated_Fat
df['Carbohydrates'] = Carbohydrates
df['Sugar'] = Sugar
df['Cholesterol'] = Cholesterol
df['Sodium'] = Sodium
df['Protein'] = Protein
df['Vitamin_K'] = Vitamin_K
df['Vitamin_A'] = Vitamin_A
df['Vitamin_C'] = Vitamin_C
df['Manganese'] = Manganese
df['Folate'] = Folate
df['Fiber'] = Fiber
df['Copper'] = Copper
df['Magnesium'] = Magnesium
df['Phosphorus'] = Phosphorus
df['Vitamin_B6'] = Vitamin_B6
df['Potassium'] = Potassium
df['Vitamin_B1'] = Vitamin_B1
df['Iron'] = Iron
df['Vitamin_B2'] = Vitamin_B2
df['Vitamin_E'] = Vitamin_E
df['Zinc'] = Zinc
df['Vitamin_B5'] = Vitamin_B5
df['Vitamin_B3'] = Vitamin_B3
df['Calcium'] = Calcium
df['Selenium'] = Selenium

# %%
df.head()
# Out:
#   aggregateLikes                               analyzedInstructions  cheap  cookingMinutes             creditsText cuisines dairyFree                                              diets                                dishTypes extendedIngredients gaps glutenFree  healthScore      id                                              image imageType ingredient_types                                       instructions ketogenic license lowFodmap num_ingredients num_instruction_words num_steps                                          nutrition                                     nutrition_info occasions  preparationMinutes  pricePerServing readyInMinutes servings              sourceName                                          sourceUrl  spoonacularScore                               spoonacularSourceUrl sustainable                                           title  vegan vegetarian veryHealthy veryPopular  weightWatcherSmartPoints whole30                                        winePairing  \
# 0          50078  [{'name': '', 'steps': [{'number': 1, 'step': ...  False            25.0          Fat Free Vegan       []      True  [gluten free, dairy free, lacto ovo vegetarian...                              [side dish]                  []   no       True        100.0  592479  https://spoonacular.com/recipeImages/592479-55...       jpg               {}  Instructions  Heat a saucepan. Add the rinsed ...     False     NaN     False              15                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 242.6, 'Fat': 7.38, 'Saturated Fa...        []                25.0           101.23             50        6          Fat Free Vegan  http://blog.fatfreevegan.com/2013/06/kale-and-...             100.0  https://spoonacular.com/kale-and-quinoa-salad-...       False          Kale and Quinoa Salad with Black Beans   True       True        True        True                       6.0   False                                                 {}
# 1          67131  [{'name': '', 'steps': [{'number': 1, 'step': ...  False            10.0  Two Peas and Their Pod       []      True          [dairy free, lacto ovo vegetarian, vegan]  [lunch, main course, main dish, dinner]                  []   no      False        100.0  547775  https://spoonacular.com/recipeImages/547775-55...       jpg               {}  1. Bring water to a boil in a medium sized pot...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 484.43, 'Fat': 16.17, 'Saturated ...        []                 5.0           171.39             15        2  Two Peas and Their Pod  http://www.twopeasandtheirpod.com/creamy-avoca...             100.0  https://spoonacular.com/creamy-avocado-pasta-5...       False                            Creamy Avocado Pasta   True       True        True        True                      13.0   False  {'pairedWines': [], 'pairingText': 'No one win...
# 2         142071  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             5.0  Two Peas and Their Pod       []      True                 [dairy free, lacto ovo vegetarian]                              [side dish]                  []   no      False         95.0  818941  https://spoonacular.com/recipeImages/818941-55...       jpg               {}  Spray a small skillet with non-stick cooking s...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 277.24, 'Fat': 15.9, 'Saturated F...        []                 5.0           160.46             10        1  Two Peas and Their Pod  http://www.twopeasandtheirpod.com/avocado-toas...             100.0  https://spoonacular.com/avocado-toast-with-egg...       False  Avocado Toast with Eggs, Spinach, and Tomatoes  False       True        True        True                       7.0   False  {'pairedWines': [], 'pairingText': '', 'produc...
# 3           7119  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             5.0           Oh My Veggies       []      True  [gluten free, dairy free, lacto ovo vegetarian...                              [side dish]                  []   no       True        100.0  495111  https://spoonacular.com/recipeImages/495111-55...       jpg               {}  Heat sesame oil in a large skillet or wok over...     False     NaN     False               7                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 72.07, 'Fat': 3.56, 'Saturated Fa...        []                10.0            51.22             15        4           Oh My Veggies  http://ohmyveggies.com/recipe-citrus-sesame-kale/             100.0  https://spoonacular.com/citrus-sesame-kale-495111       False                              Citrus Sesame Kale   True       True        True        True                       1.0   False                                                 {}
# 4         231494  [{'name': '', 'steps': [{'number': 1, 'step': ...  False             0.0               Food Babe       []     False                              [gluten free, primal]                                  [salad]                  []   no       True         96.0  689502  https://spoonacular.com/recipeImages/689502-55...       jpg               {}  In a food processor, process kale into small c...     False     NaN     False               8                     0         0  {'nutrients': [{'title': 'Calories', 'amount':...  {'Calories': 441.93, 'Fat': 33.36, 'Saturated ...        []                10.0           279.17             10        2               Food Babe  http://foodbabe.com/2013/05/08/melt-in-your-mo...             100.0  https://spoonacular.com/melt-in-your-mouth-kal...       False                   Melt In Your Mouth Kale Salad  False      False        True        True                      11.0   False                                                 {}
#
#    Calories    Fat  Saturated_Fat  Carbohydrates  Sugar  Cholesterol  Sodium  Protein  Vitamin_K  Vitamin_A  Vitamin_C  Manganese  Folate  Fiber  Copper  Magnesium  Phosphorus  Vitamin_B6  Potassium  Vitamin_B1  Iron  Vitamin_B2  Vitamin_E  Zinc  Vitamin_B5  Vitamin_B3  Calcium  Selenium
# 0    242.60   7.38           1.03          37.19   1.80          0.0  250.66     9.79     142.68    4183.66      48.48       1.01  160.25   8.84    0.63     111.48      239.17        0.38     667.61        0.28  2.98        0.21       1.82  1.80        0.91        1.72    69.53      3.59
# 1    484.43  16.17           2.38          78.08   3.95          0.0  599.51    15.36      31.03    2618.17     108.44       2.86  166.19   8.42    0.60     161.21      295.36        0.69     852.80        0.53  4.03        0.32       3.33  2.88        2.50        6.88    56.76     62.80
# 2    277.24  15.90           2.36          22.41   2.90          0.0  446.21    13.71     168.17    2960.71      18.56       1.02  156.59   9.33    0.35      83.28      134.02        0.38     835.23        0.19  2.11        0.54       2.84  1.33        1.74        3.36    76.83     25.20
# 3     72.07   3.56           0.47           8.58   0.41          0.0  158.35     4.14     599.75    8505.00     104.44       0.61   29.09   0.00    1.32      45.25       89.50        0.25     440.62        0.11  1.47        0.12       0.00  0.58        0.00        1.01   139.68      1.24
# 4    441.93  33.36           4.33          32.12  20.69          6.8  381.72    12.02     481.49    6599.81      85.22       3.52   37.80   2.93    1.54     130.48      354.60        0.30     761.30        0.24  3.75        0.23       4.22  2.99        0.24        2.56   243.24      3.28
